# %% [markdown]
# <a href="https://colab.research.google.com/github/iamrajveer759/Data-Science-With-Machine-Learning/blob/main/pythonday2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ***String Methods***
#
# ### **1. strip()**
#
# ↪  Use: Removes spaces from the start and end of a string.
#
#
#
# ```
# text = "  data science  "
# clean_text = text.strip()
# print(clean_text)   # data science
#
#
# ```
#
#
# ### **2. lower() and upper()**
#
# ↪  Purpose: Convert all characters in a string to lowercase or uppercase.
#
#
#
# ```
# text = "Data Science"
# print(text.lower())  # Output: data science
# print(text.upper())  # Output: DATA SCIENCE
#
# ```
#
#
#
# ### **3. strip(), lstrip(), rstrip()**
#
# ↪  Purpose: Remove unwanted spaces or characters from the beginning (lstrip()), end (rstrip()), or both ends (strip()) of a string.
#
# ↪  Usage: Useful for cleaning up messy data inputs.
#
# ```
# text = "  Data Science  "
# print(text.strip())  # Output: Data Science
#
# ```
#
#
# ### **4. split()**
#
# ↪ Purpose: Split a string into a list of words or parts using a delimiter.
#
# ↪  Why It's Important: Splitting text into components (like words) is crucial for tasks like tokenization in natural language processing (NLP).
#
# ```
# text = "data science is awesome"
# words = text.split()  # Output: ['data', 'science', 'is', 'awesome']
#
# ```
#
#
# ### **5. replace()**
#
# ↪ Purpose: Replace occurrences of a substring with another substring.
#
# ↪  Why It's Important: Essential for cleaning text, correcting typos, or normalizing data formats.
#
# ```
# text = "data science is awesome"
# new_text = text.replace("awesome", "amazing")  # Output: "data science is amazing"
#
# ```

# %% [markdown]
# ## **List, Tuple , Dictionary and Set**
#
# ↪ These are called compound data types
#
# ↪ one of the key types of data structures in Python.
#
# ## ***List***
#
# ↪  Store  multiple value inside of the single veriables.
#
#
# ↪ A list is a collection of items (elements) that are ordered and changeable (mutable).
#
# ↪ Lists are written with square brackets [], and items are separated by commas.
#
# ```
# fruits = ["apple", "banana", "cherry"]
# print(fruits) =>output  ['apple', 'banana', 'cherry']
# ```
#
# ↪ Access by Index: Use the index number to access a specific item.
#
# ↪ Indexing starts at 0.
#
# ↪ List are Mutable modified after they are created we can add,remove,other function use
#
#
# ```
# fruits = fruits = ["apple", False, 1,1.2]  #Also work
# print(fruits) =>output  ['apple', False, 1, 1.2]
# ```
#
#
#
# ##***Methods in List***
#
#
# ## **1. append()**
#
# ↪  Use: Adds an item to the end of the list.
#
#
#
# ```
# fruits = ["apple", "banana"]
# fruits.append("cherry")
# print(fruits)  # Output: ['apple', 'banana', 'cherry']
#
# ```
#
#
#
#
# ## **2. insert()**
#
# ↪  Use: Adds an item at a specified index.
#
#
#
# ```
# fruits = ["apple", "cherry"]
# fruits.insert(1, "banana")
# print(fruits)  # Output: ['apple', 'banana', 'cherry']
#
#
# ```
#
#
#
# ## **3. remove()**
#
# ↪ Use: Removes the first item with the specified value.
#
#
#
# ```
#
# fruits = ["apple", "banana", "cherry"]
# fruits.remove("banana")
# print(fruits)  # Output: ['apple', 'cherry']
#
#
# ```
#
#
#
#
# ## **4. pop()**
#
# ↪ Use: Removes the item at the specified index (or the last item if no index is specified).
#
#
# ```
#
# fruits = ["apple", "banana", "cherry"]
# fruits.pop(1)
# print(fruits)  # Output: ['apple', 'cherry']
#
# ```
#
#
# ## **5.clear()**
#
# ↪ Use: Removes all items from the list.
#
#
# ```
# fruits = ["apple", "banana", "cherry"]
# fruits.clear()
# print(fruits)  # Output: []
#
#
# ```
#
#
#
# ## **6.sort()**
#
# ↪ Use: Sorts the list in ascending order (by default).
#
# ```
# fruits = ["cherry", "banana", "apple"]
# fruits.sort()
# print(fruits)  # Output: ['apple', 'banana', 'cherry']
#
# ```
#
#
#
# ## **7.reverse()**
#
# ↪ Use: Reverses the order of the list.
#
# ```
# fruits = ["apple", "banana", "cherry"]
# fruits.reverse()
# print(fruits)  # Output: ['cherry', 'banana', 'apple']
#
#
# ```

# %% [markdown]
# ## **Tuple**
#
# ↪ Definition: A tuple is a collection of items that is ordered and unchangeable (immutable).
#
# ↪ Syntax: Tuples are written with round brackets ().
#
#
#
#
# ```
# # Creating a Tuple
# fruits = ("apple", "banana", "cherry")
# print(fruits)
#
# ```
#
#
# ## **Immutable Nature of Tuples**
#
# ↪ You cannot change, add, or remove items once a tuple is created. This immutability makes tuples useful for fixed collections of items.
#
#
#
# ```
# fruits = ("apple", "banana", "cherry")
# # fruits[1] = "blueberry"  # This will raise an error
#
# ```

# %% [markdown]
# ## **Sets**
#
# ↪ Definition: A set is a collection of unique items that is unordered and unindexed..
#
# ↪ Syntax: Sets are written with curly brackets {}..
#
#
# ↪  Sets themselves are mutable: You can add or remove elements.
#
# ↪ Elements inside a set must be immutable: This is to ensure consistent behavior and efficient operation of the set data structure.
#
#
# ```
# fruits = {"apple", "banana", "cherry"}
# ```

# %% [markdown]
# ## **Dictionary**
#
# ↪ Definition: A dictionary is a collection of key-value pairs. It is unordered, changeable (mutable), and does not allow duplicates for keys.
#
# ↪ Syntax: Dictionaries are written with curly brackets {}, with each key-value pair separated by a colon :
#
#
# ```
# student = {
#     "name": "Alice",
#     "age": 25,
#     "courses": ["Math", "Computer Science"]
# }
#
#
# ```
#
#
#
# ##**Nasted Dictionary**
#
# ↪  inside another dictionary
#
#
#
# ```
# students = {
#     "student1": {
#         "name": "Alice",
#         "age": 25,
#         "courses": ["Math", "Computer Science"]
#     },
#     "student2": {
#         "name": "Bob",
#         "age": 22,
#         "courses": ["Biology", "Chemistry"]
#     }
# }
#
#
# ```
