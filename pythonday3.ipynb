# %% [markdown]
# <a href="https://colab.research.google.com/github/iamrajveer759/Data-Science-With-Machine-Learning/blob/main/pythonday3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Operators**
#
# ↪ Operators are tools that perform operations on variables and values.
#
# ## **1. Arithmetic Operators:**
#
# ↪ Perform basic mathematical operations.
# ![1.png](data:image/png;base64,...)
#
#
# ## **2. Comparison Operators::**
#
# ↪ Compare two values and return True or False.
#
# ![2.png](data:image/png;base64,...)
#
#
#
# ## **3. Assignment Operators:**
#
# ↪Assign values to variables.
#
#
# ![3.png](data:image/png;base64,...)
#
#
# ## **4. Logical Operators:**
#
# ↪ Combine conditional statements.
#
#
#
#
# ![4.png](data:image/png;base64,...)
